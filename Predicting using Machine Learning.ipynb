# %%
import pandas as pd

# %% [markdown]
# ## Load the csv file

# %%
stats = pd.read_csv("player_mvp_stats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14692       14692   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14693       14693     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14694       14694  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14695       14695      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14696       14696      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# 0          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 1          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 2          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 3          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 4          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# ...        ...    ...                 ...  ..  ..    ...  ...    ...    ...
# 14692      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14693      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14694      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14695      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14696      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
#
#         SRS
# 0      6.73
# 1      6.73
# 2      6.73
# 3      6.73
# 4      6.73
# ...     ...
# 14692 -0.45
# 14693 -0.45
# 14694 -0.45
# 14695 -0.45
# 14696 -0.45
#
# [14697 rows x 42 columns]

# %% [markdown]
# ## Perform cleaning

# %%
del stats["Unnamed: 0"]

# %%
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 14692   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 14693     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 14694  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 14695      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 14696      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# 0          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 1          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 2          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 3          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 4          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# ...        ...    ...                 ...  ..  ..    ...  ...    ...    ...
# 14692      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14693      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14694      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14695      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14696      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
#
#         SRS
# 0      6.73
# 1      6.73
# 2      6.73
# 3      6.73
# 4      6.73
# ...     ...
# 14692 -0.45
# 14693 -0.45
# 14694 -0.45
# 14695 -0.45
# 14696 -0.45
#
# [14697 rows x 41 columns]

# %%
pd.isnull(stats)
# Out:
#        Player    Pos    Age     Tm      G     GS     MP     FG    FGA    FG%  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14692   False  False  False  False  False  False  False  False  False  False
# 14693   False  False  False  False  False  False  False  False  False  False
# 14694   False  False  False  False  False  False  False  False  False  False
# 14695   False  False  False  False  False  False  False  False  False  False
# 14696   False  False  False  False  False  False  False  False  False  False
#
#        ...  Pts Max  Share   Team      W      L   W/L%     GB   PS/G   PA/G  \
# 0      ...    False  False  False  False  False  False  False  False  False
# 1      ...    False  False  False  False  False  False  False  False  False
# 2      ...    False  False  False  False  False  False  False  False  False
# 3      ...    False  False  False  False  False  False  False  False  False
# 4      ...    False  False  False  False  False  False  False  False  False
# ...    ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14692  ...    False  False  False  False  False  False  False  False  False
# 14693  ...    False  False  False  False  False  False  False  False  False
# 14694  ...    False  False  False  False  False  False  False  False  False
# 14695  ...    False  False  False  False  False  False  False  False  False
# 14696  ...    False  False  False  False  False  False  False  False  False
#
#          SRS
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 14692  False
# 14693  False
# 14694  False
# 14695  False
# 14696  False
#
# [14697 rows x 41 columns]

# %%
stats.isnull().sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          59
# 3P            0
# 3PA           0
# 3P%        2086
# 2P            0
# 2PA           0
# 2P%         100
# eFG%         59
# FT            0
# FTA           0
# FT%         521
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats[stats["3P%"].isnull()][["Player","3PA"]]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14666    Evan Eschmeyer  0.0
# 14667  Gheorghe Mureșan  0.0
# 14669     Jim McIlvaine  0.0
# 14675  Mark Hendrickson  0.0
# 14676      Michael Cage  0.0
#
# [2086 rows x 2 columns]

# %%
stats[stats["3P%"].isnull()][["Player","FTA"]]
# Out:
#                  Player  FTA
# 2        Elden Campbell  0.9
# 3         Irving Thomas  0.8
# 18           Jack Haley  0.6
# 20          Keith Owens  0.5
# 30      Benoit Benjamin  1.8
# ...                 ...  ...
# 14666    Evan Eschmeyer  1.0
# 14667  Gheorghe Mureșan  1.3
# 14669     Jim McIlvaine  0.8
# 14675  Mark Hendrickson  0.3
# 14676      Michael Cage  0.2
#
# [2086 rows x 2 columns]

# %%
stats[stats["3P%"].isnull()][["Player","3P"]]
# Out:
#                  Player   3P
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14666    Evan Eschmeyer  0.0
# 14667  Gheorghe Mureșan  0.0
# 14669     Jim McIlvaine  0.0
# 14675  Mark Hendrickson  0.0
# 14676      Michael Cage  0.0
#
# [2086 rows x 2 columns]

# %%
stats=stats.fillna(0)

# %%
stats.isnull().sum()
# Out:
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# Year       0
# Pts Won    0
# Pts Max    0
# Share      0
# Team       0
# W          0
# L          0
# W/L%       0
# GB         0
# PS/G       0
# PA/G       0
# SRS        0
# dtype: int64

# %% [markdown]
# ## Training a machine learning model

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
predictors = ["Age", "G", "GS", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%','GB', 'PS/G', 'PA/G', 'SRS']

# %%
train = stats[stats["Year"] < 2022]

# %%
test = stats[stats["Year"] == 2022]

# %%
# Ridge regression is a type of linear regression which shrinks the cofficients to avoid overfitting
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=0.1)

# %%
reg.fit(train[predictors],train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
#        -6.75624134e-03,  4.78515641e-02, -1.39395458e-02,  8.73941224e-04,
#        -1.38586169e-02,  3.03441286e-02, -3.28341209e-02,  5.72823858e-02,
#         5.34514471e-02,  1.01423755e-03, -6.30706785e-03,  1.19408616e-02,
#         3.18487624e-02,  1.06195640e-02, -7.93374524e-04,  5.38417674e-04,
#         1.58632188e-02,  2.34441473e-03, -3.16673478e-02,  5.84651411e-03,
#         4.78986607e-03,  8.36806098e-03, -4.33091524e-02, -2.78623105e-02,
#        -1.12838495e-02, -1.81923175e-02, -3.52836667e-03, -6.45217913e-02,
#        -7.90670373e-03,  1.69467983e-02, -2.37744574e-02, -2.58360382e-02,
#        -1.49620528e-02, -2.48808564e-02,  3.15622289e-02, -1.90519475e-02,
#         1.68479351e-02, -2.29779097e-02, -7.82380858e-03,  8.67756042e-03,
#        -1.78697687e-02, -9.06680766e-03,  5.28629376e-03,  1.34961690e-03,
#        -5.49668456e-02])

# %%
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
predictions
# Out:
#        predictions
# 648       0.013638
# 649      -0.027154
# 650      -0.005272
# 651       0.016934
# 652      -0.003576
# ...            ...
# 12508    -0.017870
# 12509    -0.009067
# 12510     0.005286
# 12511     0.001350
# 12512    -0.054967
#
# [605 rows x 1 columns]

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination
# Out:
#                 Player  Share  predictions
# 648       Aaron Gordon    0.0     0.013638
# 649      Austin Rivers    0.0    -0.027154
# 650            Bol Bol    0.0    -0.005272
# 651       Bones Hyland    0.0     0.016934
# 652        Bryn Forbes    0.0    -0.003576
# ...                ...    ...          ...
# 12508     Micah Potter    0.0    -0.017870
# 12509  Rodney McGruder    0.0    -0.009067
# 12510        Saben Lee    0.0     0.005286
# 12511       Saddiq Bey    0.0     0.001350
# 12512   Trayvon Palmer    0.0    -0.054967
#
# [605 rows x 3 columns]

# %%
combination.sort_values("Share", ascending=False).head(20)
# Out:
#                       Player  Share  predictions
# 663             Nikola Jokić  0.875     0.189411
# 837              Joel Embiid  0.706     0.191151
# 11678  Giannis Antetokounmpo  0.595     0.219107
# 907             Devin Booker  0.216     0.092999
# 11469            Luka Dončić  0.146     0.156888
# 1179            Jayson Tatum  0.043     0.095388
# 12226              Ja Morant  0.010     0.122080
# 6398           Stephen Curry  0.004     0.093766
# 905               Chris Paul  0.002     0.080390
# 8241            LeBron James  0.001     0.157861
# 3938           DeMar DeRozan  0.001     0.101564
# 6185            Kevin Durant  0.001     0.140660
# 9752              OG Anunoby  0.000     0.000385
# 9749       Justin Champagnie  0.000    -0.012819
# 9750              Khem Birch  0.000    -0.024550
# 9751           Malachi Flynn  0.000     0.003610
# 9775        Arnoldas Kulboka  0.000     0.009714
# 9756          Scottie Barnes  0.000     0.006431
# 9759           Yuta Watanabe  0.000     0.007300
# 9754        Precious Achiuwa  0.000    -0.008667

# %% [markdown]
# ## Identifying an error metric

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(combination["Share"],combination["predictions"])
# Out:
# 0.0022474562763311876

# %%
combination["Share"].value_counts()
# Out:
# 0.000    593
# 0.001      3
# 0.146      1
# 0.043      1
# 0.002      1
# 0.216      1
# 0.004      1
# 0.010      1
# 0.595      1
# 0.706      1
# 0.875      1
# Name: Share, dtype: int64

# %%
combination = combination.sort_values("Share",ascending=False)
combination["Rk"] = list(range(1,combination.shape[0]+1))

# %%
combination
# Out:
#                       Player  Share  predictions   Rk
# 663             Nikola Jokić  0.875     0.189411    1
# 837              Joel Embiid  0.706     0.191151    2
# 11678  Giannis Antetokounmpo  0.595     0.219107    3
# 907             Devin Booker  0.216     0.092999    4
# 11469            Luka Dončić  0.146     0.156888    5
# ...                      ...    ...          ...  ...
# 12507      Marvin Bagley III  0.000     0.008678  601
# 12508           Micah Potter  0.000    -0.017870  602
# 12509        Rodney McGruder  0.000    -0.009067  603
# 12510              Saben Lee  0.000     0.005286  604
# 12512         Trayvon Palmer  0.000    -0.054967  605
#
# [605 rows x 4 columns]

# %%
combination = combination.sort_values("predictions",ascending=False)
combination["Predicted_Rk"] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions   Rk  Predicted_Rk
# 11678  Giannis Antetokounmpo  0.595     0.219107    3             1
# 837              Joel Embiid  0.706     0.191151    2             2
# 663             Nikola Jokić  0.875     0.189411    1             3
# 8241            LeBron James  0.001     0.157861   12             4
# 11469            Luka Dončić  0.146     0.156888    5             5
# 6185            Kevin Durant  0.001     0.140660   10             6
# 12226              Ja Morant  0.010     0.122080    7             7
# 11820             Trae Young  0.000     0.110532  514             8
# 8231           Anthony Davis  0.000     0.108509  318             9
# 836             James Harden  0.000     0.103964   41            10

# %%
combination.sort_values("Share",ascending=False).head(10)
# Out:
#                       Player  Share  predictions  Rk  Predicted_Rk
# 663             Nikola Jokić  0.875     0.189411   1             3
# 837              Joel Embiid  0.706     0.191151   2             2
# 11678  Giannis Antetokounmpo  0.595     0.219107   3             1
# 907             Devin Booker  0.216     0.092999   4            16
# 11469            Luka Dončić  0.146     0.156888   5             5
# 1179            Jayson Tatum  0.043     0.095388   6            14
# 12226              Ja Morant  0.010     0.122080   7             7
# 6398           Stephen Curry  0.004     0.093766   8            15
# 905               Chris Paul  0.002     0.080390   9            21
# 3938           DeMar DeRozan  0.001     0.101564  11            11

# %%
def find_ap(combination):
    actual = combination.sort_values("Share",ascending=False).head(5)
    predicted = combination.sort_values("predictions",ascending=False)
    ps = []
    found = 0
    seen = 1
    
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found/seen)
        seen += 1

    return ps

# %%
find_ap(combination)
# Out:
# [1.0, 1.0, 1.0, 0.8, 0.3125]

# %%
def find_ap(combination):
    actual = combination.sort_values("Share",ascending=False).head(5)
    predicted = combination.sort_values("predictions",ascending=False)
    ps = []
    found = 0
    seen = 1
    
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found/seen)
        seen += 1

    return sum(ps)/len(ps)

# %%
find_ap(combination)
# Out:
# 0.8225

# %% [markdown]
# ## Implementating backtesting to predict each year

# %%
years = list(range(1991,2023))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps)/len(aps)
# Out:
# 0.715194005962712

# %%
def add_ranks(combination):
    combination = combination.sort_values("Share",ascending=False)
    combination["Rk"] = list(range(1,combination.shape[0]+1))
    combination = combination.sort_values("predictions",ascending=False)
    combination["Predicted_Rk"] = list(range(1,combination.shape[0]+1))
    combination["Diff"] = (combination["Rk"] - combination["Predicted_Rk"])
    return combination

# %%
add_ranks(all_predictions[1])
# Out:
#                  Player  Share  predictions   Rk  Predicted_Rk  Diff
# 13154  Shaquille O'Neal  0.006     0.198218   10             1     9
# 1710        Karl Malone  0.857     0.192360    1             2    -1
# 10976    Michael Jordan  0.832     0.167672    2             3    -1
# 12591   Hakeem Olajuwon  0.083     0.136398    7             4     3
# 10274    David Robinson  0.000     0.131097   36             5    31
# ...                 ...    ...          ...  ...           ...   ...
# 13748     Eric Montross  0.000    -0.043778  164           437  -273
# 5171     Pervis Ellison  0.000    -0.046987  423           438   -15
# 10841      Popeye Jones  0.000    -0.048873  199           439  -240
# 10970     Dennis Rodman  0.000    -0.054581  191           440  -249
# 7087      Melvin Booker  0.000    -0.055141  341           441  -100
#
# [441 rows x 6 columns]

# %%
add_ranks(all_predictions[1]).sort_values("Diff",ascending=False)
# Out:
#                   Player  Share  predictions   Rk  Predicted_Rk  Diff
# 4910           Matt Fish    0.0     0.038290  440            46   394
# 4899         Bruce Bowen    0.0     0.077562  398            13   385
# 3775     Rasheed Wallace    0.0     0.049934  414            29   385
# 5370   Anfernee Hardaway    0.0     0.058426  391            22   369
# 4905         James Scott    0.0     0.040938  392            42   350
# ...                  ...    ...          ...  ...           ...   ...
# 10281       Sean Elliott    0.0    -0.019071   23           374  -351
# 85            A.C. Green    0.0    -0.024904   38           395  -357
# 10835       Hubert Davis    0.0    -0.026872   43           403  -360
# 9928    Lorenzo Williams    0.0    -0.036781   64           428  -364
# 10279       Joe Courtney    0.0    -0.026307   30           400  -370
#
# [441 rows x 6 columns]

# %%
ranking = add_ranks(all_predictions[1])
ranking[ranking["Rk"]<6].sort_values("Diff",ascending=False)
# Out:
#                Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1710      Karl Malone  0.857     0.192360   1             2    -1
# 10976  Michael Jordan  0.832     0.167672   2             3    -1
# 970        Grant Hill  0.327     0.128664   3             6    -3
# 4912     Tim Hardaway  0.207     0.059992   4            20   -16
# 8642        Glen Rice  0.117     0.033122   5            53   -48

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps)/len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.715194005962712

# %% [markdown]
# ## Diagnosing model performance

# %%
all_predictions[all_predictions["Rk"] <= 5].sort_values("Diff").head(10)
# Out:
#                  Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1334         Jason Kidd  0.712     0.027957   2            52   -50
# 8642          Glen Rice  0.117     0.033122   5            53   -48
# 5420         Steve Nash  0.839     0.032686   1            47   -46
# 8910    Peja Stojaković  0.228     0.035581   4            39   -35
# 5438         Steve Nash  0.739     0.051338   1            35   -34
# 13331       Joakim Noah  0.258     0.047390   4            37   -33
# 3849   Chauncey Billups  0.344     0.051437   5            34   -29
# 1499         Chris Paul  0.138     0.073983   5            33   -28
# 5453         Steve Nash  0.785     0.070791   2            23   -21
# 4912       Tim Hardaway  0.207     0.059992   4            20   -16

# %%
reg.coef_
# Out:
# array([ 3.32239005e-04,  9.77210915e-05,  5.33127153e-06, -4.08146984e-03,
#         3.66383678e-03,  4.90043612e-03, -1.51275461e-01,  2.07793831e-03,
#        -1.03800693e-02, -9.71408942e-03,  1.54303271e-02, -1.63224726e-02,
#         6.08153038e-03,  8.32333172e-02, -6.61251053e-03,  1.05390368e-02,
#        -4.53444601e-03,  2.11632114e-02,  3.32210414e-02, -2.63605392e-02,
#         7.09105921e-03,  1.24724224e-02,  1.08281413e-02, -8.90038517e-03,
#        -2.34823071e-03,  7.10466977e-03,  1.62000468e-04, -3.25972748e-04,
#         2.40111814e-02,  3.25036343e-04, -4.49374655e-04, -3.79731747e-04,
#        -6.49265654e-04])

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1)
# Out:
#            0     1
# 0   0.000332   Age
# 1   0.000098     G
# 2   0.000005    GS
# 3  -0.004081    MP
# 4   0.003664    FG
# 5   0.004900   FGA
# 6  -0.151275   FG%
# 7   0.002078    3P
# 8  -0.010380   3PA
# 9  -0.009714   3P%
# 10  0.015430    2P
# 11 -0.016322   2PA
# 12  0.006082   2P%
# 13  0.083233  eFG%
# 14 -0.006613    FT
# 15  0.010539   FTA
# 16 -0.004534   FT%
# 17  0.021163   ORB
# 18  0.033221   DRB
# 19 -0.026361   TRB
# 20  0.007091   AST
# 21  0.012472   STL
# 22  0.010828   BLK
# 23 -0.008900   TOV
# 24 -0.002348    PF
# 25  0.007105   PTS
# 26  0.000162     W
# 27 -0.000326     L
# 28  0.024011  W/L%
# 29  0.000325    GB
# 30 -0.000449  PS/G
# 31 -0.000380  PA/G
# 32 -0.000649   SRS

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.083233  eFG%
# 18  0.033221   DRB
# 28  0.024011  W/L%
# 17  0.021163   ORB
# 10  0.015430    2P
# 21  0.012472   STL
# 22  0.010828   BLK
# 15  0.010539   FTA
# 25  0.007105   PTS
# 20  0.007091   AST
# 12  0.006082   2P%
# 5   0.004900   FGA
# 4   0.003664    FG
# 7   0.002078    3P
# 0   0.000332   Age
# 29  0.000325    GB
# 26  0.000162     W
# 1   0.000098     G
# 2   0.000005    GS
# 27 -0.000326     L
# 31 -0.000380  PA/G
# 30 -0.000449  PS/G
# 32 -0.000649   SRS
# 24 -0.002348    PF
# 3  -0.004081    MP
# 16 -0.004534   FT%
# 14 -0.006613    FT
# 23 -0.008900   TOV
# 9  -0.009714   3P%
# 8  -0.010380   3PA
# 11 -0.016322   2PA
# 19 -0.026361   TRB
# 6  -0.151275   FG%

# %% [markdown]
# ## Adding more predictors

# %%
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())

# %%
stat_ratios
# Out:
#             PTS       AST       STL       BLK        3P  Year
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0
# ...         ...       ...       ...       ...       ...   ...
# 14692  0.735752  0.819562  0.479763  1.528302  0.650951   1.0
# 14693  0.071202  0.000000  0.000000  0.000000  0.130190   1.0
# 14694  1.281633  0.601012  1.119447  2.547170  0.520761   1.0
# 14695  0.474679  0.218550  0.319842  1.273585  0.650951   1.0
# 14696  1.008693  0.655649  1.119447  0.509434  2.343424   1.0
#
# [14697 rows x 6 columns]

# %%
stats[["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]] = stat_ratios[["PTS", "AST", "STL", "BLK", "3P"]]

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   W/L%  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.707
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  0.707
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  0.707
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  0.707
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  0.707
#
#     GB   PS/G  PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R
# 0  5.0  106.3  99.6  6.73  1.013334  0.420714  0.961127  0.673469  0.508587
# 1  5.0  106.3  99.6  6.73  1.614653  1.028412  1.647646  0.673469  4.577279
# 2  5.0  106.3  99.6  6.73  0.311795  0.093492  0.274608  1.571429  0.000000
# 3  5.0  106.3  99.6  6.73  0.200440  0.186984  0.274608  0.000000  0.000000
# 4  5.0  106.3  99.6  6.73  2.383005  1.636110  1.784950  0.897959  1.525760
#
# [5 rows x 46 columns]

# %%
predictors += ["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7238998493531219

# %%
stats["Pos"].unique()
# Out:
# array(['PF', 'SG', 'SF', 'PG', 'C', 'PG-SG', 'PF-SF', 'SG-PG', 'PF-C',
#        'SG-SF', 'SF-PF', 'SF-SG', 'C-PF', 'SG-PF', 'PG-SF', 'SG-PG-SF',
#        'SF-C'], dtype=object)

# %%
stats["NPos"] = stats["Pos"].astype("category").cat.codes

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   PS/G  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  106.3
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  106.3
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  106.3
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  106.3
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  106.3
#
#    PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R  NPos  NTm
# 0  99.6  6.73  1.013334  0.420714  0.961127  0.673469  0.508587     2   15
# 1  99.6  6.73  1.614653  1.028412  1.647646  0.673469  4.577279    12   15
# 2  99.6  6.73  0.311795  0.093492  0.274608  1.571429  0.000000     2   15
# 3  99.6  6.73  0.200440  0.186984  0.274608  0.000000  0.000000     2   15
# 4  99.6  6.73  2.383005  1.636110  1.784950  0.897959  1.525760     8   15
#
# [5 rows x 48 columns]

# %%
stats["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'CHI', 'GSW', 'IND',
#        'WAS', 'MIN', 'BOS', 'HOU', 'DEN', 'ORL', 'NOH', 'TOR', 'SAC',
#        'CHO', 'PHI', 'POR', 'DET', 'OKC', 'UTA', 'MIL', 'VAN', 'SEA',
#        'NJN', 'NOK', 'LAC', 'ATL', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
stats["NTm"] = stats["Tm"].astype("category").cat.codes

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   PS/G  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  106.3
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  106.3
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  106.3
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  106.3
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  106.3
#
#    PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R  NPos  NTm
# 0  99.6  6.73  1.013334  0.420714  0.961127  0.673469  0.508587     2   15
# 1  99.6  6.73  1.614653  1.028412  1.647646  0.673469  4.577279    12   15
# 2  99.6  6.73  0.311795  0.093492  0.274608  1.571429  0.000000     2   15
# 3  99.6  6.73  0.200440  0.186984  0.274608  0.000000  0.000000     2   15
# 4  99.6  6.73  2.383005  1.636110  1.784950  0.897959  1.525760     8   15
#
# [5 rows x 48 columns]

# %%
stats["NTm"].value_counts()
# Out:
# 7     522
# 8     514
# 27    514
# 17    512
# 14    510
# 11    508
# 0     506
# 12    505
# 1     501
# 9     501
# 31    497
# 26    496
# 15    496
# 18    494
# 13    494
# 5     493
# 24    489
# 10    486
# 34    486
# 30    486
# 28    485
# 29    484
# 19    482
# 33    441
# 36    410
# 16    353
# 20    343
# 32    263
# 25    240
# 2     182
# 4     177
# 23    163
# 3     157
# 21    143
# 6     130
# 37    114
# 35     88
# 22     32
# Name: NTm, dtype: int64

# %% [markdown]
# ## Using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)

# %%
mean_ap, aps, all_predictions = backtest(stats, rf, years[29:], predictors)

# %%
mean_ap
# Out:
# 0.888989898989899

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[29:], predictors)

# %%
mean_ap
# Out:
# 0.8779642579642579
